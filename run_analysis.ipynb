# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

crime_data = pd.read_csv('~/final-project-mkhan58/data/processed/crime_and_election_data.csv')
#crime_data = crime_data.drop(columns=['Unnamed: 0'])

#Dimensions
num_rows, num_columns = crime_data.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)

#Check data types
crime_data.dtypes

#Check for duplicates
duplicates_values = crime_data.duplicated().sum()
print("Missing values in DataFrame:")
print(duplicates_values)

#Check for NA
missing_values = crime_data.isnull().sum()
print("Missing values in DataFrame:")
print(missing_values)

#Handle Missing Values
#Columns wiht missing values: Rape, Total Violent, and Arson
missingval_col = ['Rape', 'Total Violent', 'Arson']

#Get mean within each column
mean_values = crime_data[missingval_col].mean() 

#Fill with mean imputation
crime_data[missingval_col] = crime_data[missingval_col].fillna(mean_values)


#Descriptive Statistics
#Get mean within each column
mean_values = crime_data[missingval_col].mean() 
 
statistics = crime_only.describe().sort_values(by='mean', axis=1, ascending = False)
statistics 


#Get average crime rate of red vs blue
grouped_data = crime_data.groupby('blue')
total_crimes = grouped_data[['Murder/Manslaughter', 'Rape', 'Robbery', 'Assault', 'Burglary', 'Larceny/Theft', 'Vehicle Theft', 'Arson']].mean()
total_crimes


#T-test on Mean Difference on Crime Rate red vs blue
red_states = crime_data[crime_data['blue'] == 'Red'][['Murder/Manslaughter', 'Rape', 'Robbery', 'Assault', 'Burglary', 'Larceny/Theft', 'Vehicle Theft', 'Arson']]
blue_states = crime_data[crime_data['blue'] == 'Blue'][['Murder/Manslaughter', 'Rape', 'Robbery', 'Assault', 'Burglary', 'Larceny/Theft', 'Vehicle Theft', 'Arson']]

# Perform t-test for each crime type
for crime_type in total_crimes.columns:
    t_statistic, p_value = ttest_ind(red_states[crime_type], blue_states[crime_type])
    print(f'Test for {crime_type}:\n t-statistic = {t_statistic}\n p-value = {p_value}\n')
